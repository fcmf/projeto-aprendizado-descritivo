# %% [markdown]
# # Descoberta de Subgrupos com dia_categoria - Violência Doméstica MG 2023
#
# Este notebook aplica Subgroup Discovery (SD) considerando a nova variável `dia_categoria`, que agrupa os dias da semana em faixas significativas para análise temporal.

# %%
# Instalar a biblioteca se necessário
# !pip install pysubgroup
import pandas as pd
import pysubgroup as ps
# Out:
# Collecting pysubgroup
#   Downloading pysubgroup-0.8.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from pysubgroup) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pysubgroup) (1.15.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pysubgroup) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pysubgroup) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.0->pysubgroup) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.0->pysubgroup) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.0->pysubgroup) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pysubgroup) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pysubgroup) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pysubgroup) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pysubgroup) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pysubgroup) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pysubgroup) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pysubgroup) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->pysubgroup) (1.17.0)
# Downloading pysubgroup-0.8.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.5/70.5 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: pysubgroup
# Successfully installed pysubgroup-0.8.0

# %%
# Carregar os dados
df = pd.read_csv("violencia_domestica_2023.csv", sep=";")

# Corrigir data
def corrigir_data(valor):
    try:
        return pd.to_datetime(valor)
    except:
        try:
            num = float(valor)
            return pd.to_datetime("1899-12-30") + pd.to_timedelta(num, unit="D")
        except:
            return pd.NaT

df['data_fato_corrigida'] = df['data_fato'].apply(corrigir_data)
df['dia_da_semana'] = df['data_fato_corrigida'].dt.day_name()

# Categorizar dia_tipo e dia_categoria
df['dia_tipo'] = df['dia_da_semana'].isin(['Saturday', 'Sunday']).map({True: 'fim de semana', False: 'dia útil'})

def categorizar_dia(dia):
    if dia in ['Monday', 'Tuesday', 'Wednesday']:
        return 'segunda a quarta'
    elif dia in ['Thursday', 'Friday', 'Saturday']:
        return 'quinta a sábado'
    elif dia == 'Sunday':
        return 'domingo'
    return 'desconhecido'

df['dia_categoria'] = df['dia_da_semana'].apply(categorizar_dia)

# %%
df['target'] = (df['tentado_consumado'] == 'CONSUMADO').astype(int)

atributos = [
    'municipio_fato', 'mes', 'risp', 'rmbh',
    'natureza_delito', 'dia_tipo', 'dia_categoria'
]

df_sd = df[atributos + ['target']].dropna()

# %%
# Criar tarefa de SD
target = ps.BinaryTarget('target', True)
search_space = ps.create_selectors(df_sd, ignore=['target'])
qf = ps.WRAccQF()

task = ps.SubgroupDiscoveryTask(
    df_sd, target, search_space, qf,
    result_set_size=10, depth=3
)

# Executar SD
result = ps.SimpleDFS().execute(task)

# Exibir resultados
result.to_dataframe()
# Out:
#     quality                                           subgroup  size_sg  \
# 0  0.000850  dia_tipo=='fim de semana' AND rmbh=='3) Interi...    17387
# 1  0.000840  natureza_delito=='LESAO CORPORAL' AND rmbh=='3...     8596
# 2  0.000796                  natureza_delito=='LESAO CORPORAL'     9780
# 3  0.000622  natureza_delito=='DESCUMPRIMENTO DE MEDIDA PRO...     4029
# 4  0.000528                          dia_tipo=='fim de semana'    20876
# 5  0.000508  dia_tipo=='dia útil' AND natureza_delito=='LES...     4869
# 6  0.000489  natureza_delito=='DESCUMPRIMENTO DE MEDIDA PRO...     3163
# 7  0.000478  dia_tipo=='dia útil' AND natureza_delito=='LES...     5616
# 8  0.000470                          rmbh=='3) Interior de MG'    50484
# 9  0.000442  dia_categoria=='domingo' AND rmbh=='3) Interio...     9383
#
#    size_dataset  positives_sg  positives_dataset  size_complement  \
# 0         61536         17274              60951            44149
# 1         61536          8566              60951            52940
# 2         61536          9736              60951            51756
# 3         61536          4029              60951            57507
# 4         61536         20710              60951            40660
# 5         61536          4854              60951            56667
# 6         61536          3163              60951            58373
# 7         61536          5592              60951            55920
# 8         61536         50033              60951            11052
# 9         61536          9321              60951            52153
#
#    relative_size_sg  relative_size_complement  coverage_sg  \
# 0          0.282550                  0.717450     0.283408
# 1          0.139691                  0.860309     0.140539
# 2          0.158931                  0.841069     0.159735
# 3          0.065474                  0.934526     0.066102
# 4          0.339249                  0.660751     0.339781
# 5          0.079124                  0.920876     0.079638
# 6          0.051401                  0.948599     0.051894
# 7          0.091264                  0.908736     0.091746
# 8          0.820398                  0.179602     0.820873
# 9          0.152480                  0.847520     0.152926
#
#    coverage_complement  target_share_sg  target_share_complement  \
# 0             0.716592         0.993501                 0.989309
# 1             0.859461         0.996510                 0.989516
# 2             0.840265         0.995501                 0.989547
# 3             0.933898         1.000000                 0.989827
# 4             0.660219         0.992048                 0.989695
# 5             0.920362         0.996919                 0.989941
# 6             0.948106         1.000000                 0.989978
# 7             0.908254         0.995726                 0.989968
# 8             0.179127         0.991066                 0.987875
# 9             0.847074         0.993392                 0.989972
#
#    target_share_dataset      lift
# 0              0.990493  1.003036
# 1              0.990493  1.006074
# 2              0.990493  1.005056
# 3              0.990493  1.009598
# 4              0.990493  1.001570
# 5              0.990493  1.006488
# 6              0.990493  1.009598
# 7              0.990493  1.005283
# 8              0.990493  1.000579
# 9              0.990493  1.002927

# %%
df_result = result.to_dataframe()
df_result = df_result.set_index("subgroup")
display(df_result.sort_values('lift', ascending=False).head(10))
# Out:
#                                                      quality  size_sg  \
# subgroup
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...  0.000489     3163
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...  0.000622     4029
# dia_tipo=='dia útil' AND natureza_delito=='LESA...  0.000508     4869
# natureza_delito=='LESAO CORPORAL' AND rmbh=='3)...  0.000840     8596
# dia_tipo=='dia útil' AND natureza_delito=='LESA...  0.000478     5616
# natureza_delito=='LESAO CORPORAL'                   0.000796     9780
# dia_tipo=='fim de semana' AND rmbh=='3) Interio...  0.000850    17387
# dia_categoria=='domingo' AND rmbh=='3) Interior...  0.000442     9383
# dia_tipo=='fim de semana'                           0.000528    20876
# rmbh=='3) Interior de MG'                           0.000470    50484
#
#                                                     size_dataset  \
# subgroup
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...         61536
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...         61536
# dia_tipo=='dia útil' AND natureza_delito=='LESA...         61536
# natureza_delito=='LESAO CORPORAL' AND rmbh=='3)...         61536
# dia_tipo=='dia útil' AND natureza_delito=='LESA...         61536
# natureza_delito=='LESAO CORPORAL'                          61536
# dia_tipo=='fim de semana' AND rmbh=='3) Interio...         61536
# dia_categoria=='domingo' AND rmbh=='3) Interior...         61536
# dia_tipo=='fim de semana'                                  61536
# rmbh=='3) Interior de MG'                                  61536
#
#                                                     positives_sg  \
# subgroup
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...          3163
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...          4029
# dia_tipo=='dia útil' AND natureza_delito=='LESA...          4854
# natureza_delito=='LESAO CORPORAL' AND rmbh=='3)...          8566
# dia_tipo=='dia útil' AND natureza_delito=='LESA...          5592
# natureza_delito=='LESAO CORPORAL'                           9736
# dia_tipo=='fim de semana' AND rmbh=='3) Interio...         17274
# dia_categoria=='domingo' AND rmbh=='3) Interior...          9321
# dia_tipo=='fim de semana'                                  20710
# rmbh=='3) Interior de MG'                                  50033
#
#                                                     positives_dataset  \
# subgroup
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...              60951
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...              60951
# dia_tipo=='dia útil' AND natureza_delito=='LESA...              60951
# natureza_delito=='LESAO CORPORAL' AND rmbh=='3)...              60951
# dia_tipo=='dia útil' AND natureza_delito=='LESA...              60951
# natureza_delito=='LESAO CORPORAL'                               60951
# dia_tipo=='fim de semana' AND rmbh=='3) Interio...              60951
# dia_categoria=='domingo' AND rmbh=='3) Interior...              60951
# dia_tipo=='fim de semana'                                       60951
# rmbh=='3) Interior de MG'                                       60951
#
#                                                     size_complement  \
# subgroup
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...            58373
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...            57507
# dia_tipo=='dia útil' AND natureza_delito=='LESA...            56667
# natureza_delito=='LESAO CORPORAL' AND rmbh=='3)...            52940
# dia_tipo=='dia útil' AND natureza_delito=='LESA...            55920
# natureza_delito=='LESAO CORPORAL'                             51756
# dia_tipo=='fim de semana' AND rmbh=='3) Interio...            44149
# dia_categoria=='domingo' AND rmbh=='3) Interior...            52153
# dia_tipo=='fim de semana'                                     40660
# rmbh=='3) Interior de MG'                                     11052
#
#                                                     relative_size_sg  \
# subgroup
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...          0.051401
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...          0.065474
# dia_tipo=='dia útil' AND natureza_delito=='LESA...          0.079124
# natureza_delito=='LESAO CORPORAL' AND rmbh=='3)...          0.139691
# dia_tipo=='dia útil' AND natureza_delito=='LESA...          0.091264
# natureza_delito=='LESAO CORPORAL'                           0.158931
# dia_tipo=='fim de semana' AND rmbh=='3) Interio...          0.282550
# dia_categoria=='domingo' AND rmbh=='3) Interior...          0.152480
# dia_tipo=='fim de semana'                                   0.339249
# rmbh=='3) Interior de MG'                                   0.820398
#
#                                                     relative_size_complement  \
# subgroup
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...                  0.948599
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...                  0.934526
# dia_tipo=='dia útil' AND natureza_delito=='LESA...                  0.920876
# natureza_delito=='LESAO CORPORAL' AND rmbh=='3)...                  0.860309
# dia_tipo=='dia útil' AND natureza_delito=='LESA...                  0.908736
# natureza_delito=='LESAO CORPORAL'                                   0.841069
# dia_tipo=='fim de semana' AND rmbh=='3) Interio...                  0.717450
# dia_categoria=='domingo' AND rmbh=='3) Interior...                  0.847520
# dia_tipo=='fim de semana'                                           0.660751
# rmbh=='3) Interior de MG'                                           0.179602
#
#                                                     coverage_sg  \
# subgroup
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...     0.051894
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...     0.066102
# dia_tipo=='dia útil' AND natureza_delito=='LESA...     0.079638
# natureza_delito=='LESAO CORPORAL' AND rmbh=='3)...     0.140539
# dia_tipo=='dia útil' AND natureza_delito=='LESA...     0.091746
# natureza_delito=='LESAO CORPORAL'                      0.159735
# dia_tipo=='fim de semana' AND rmbh=='3) Interio...     0.283408
# dia_categoria=='domingo' AND rmbh=='3) Interior...     0.152926
# dia_tipo=='fim de semana'                              0.339781
# rmbh=='3) Interior de MG'                              0.820873
#
#                                                     coverage_complement  \
# subgroup
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...             0.948106
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...             0.933898
# dia_tipo=='dia útil' AND natureza_delito=='LESA...             0.920362
# natureza_delito=='LESAO CORPORAL' AND rmbh=='3)...             0.859461
# dia_tipo=='dia útil' AND natureza_delito=='LESA...             0.908254
# natureza_delito=='LESAO CORPORAL'                              0.840265
# dia_tipo=='fim de semana' AND rmbh=='3) Interio...             0.716592
# dia_categoria=='domingo' AND rmbh=='3) Interior...             0.847074
# dia_tipo=='fim de semana'                                      0.660219
# rmbh=='3) Interior de MG'                                      0.179127
#
#                                                     target_share_sg  \
# subgroup
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...         1.000000
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...         1.000000
# dia_tipo=='dia útil' AND natureza_delito=='LESA...         0.996919
# natureza_delito=='LESAO CORPORAL' AND rmbh=='3)...         0.996510
# dia_tipo=='dia útil' AND natureza_delito=='LESA...         0.995726
# natureza_delito=='LESAO CORPORAL'                          0.995501
# dia_tipo=='fim de semana' AND rmbh=='3) Interio...         0.993501
# dia_categoria=='domingo' AND rmbh=='3) Interior...         0.993392
# dia_tipo=='fim de semana'                                  0.992048
# rmbh=='3) Interior de MG'                                  0.991066
#
#                                                     target_share_complement  \
# subgroup
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...                 0.989978
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...                 0.989827
# dia_tipo=='dia útil' AND natureza_delito=='LESA...                 0.989941
# natureza_delito=='LESAO CORPORAL' AND rmbh=='3)...                 0.989516
# dia_tipo=='dia útil' AND natureza_delito=='LESA...                 0.989968
# natureza_delito=='LESAO CORPORAL'                                  0.989547
# dia_tipo=='fim de semana' AND rmbh=='3) Interio...                 0.989309
# dia_categoria=='domingo' AND rmbh=='3) Interior...                 0.989972
# dia_tipo=='fim de semana'                                          0.989695
# rmbh=='3) Interior de MG'                                          0.987875
#
#                                                     target_share_dataset  \
# subgroup
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...              0.990493
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...              0.990493
# dia_tipo=='dia útil' AND natureza_delito=='LESA...              0.990493
# natureza_delito=='LESAO CORPORAL' AND rmbh=='3)...              0.990493
# dia_tipo=='dia útil' AND natureza_delito=='LESA...              0.990493
# natureza_delito=='LESAO CORPORAL'                               0.990493
# dia_tipo=='fim de semana' AND rmbh=='3) Interio...              0.990493
# dia_categoria=='domingo' AND rmbh=='3) Interior...              0.990493
# dia_tipo=='fim de semana'                                       0.990493
# rmbh=='3) Interior de MG'                                       0.990493
#
#                                                         lift
# subgroup
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...  1.009598
# natureza_delito=='DESCUMPRIMENTO DE MEDIDA PROT...  1.009598
# dia_tipo=='dia útil' AND natureza_delito=='LESA...  1.006488
# natureza_delito=='LESAO CORPORAL' AND rmbh=='3)...  1.006074
# dia_tipo=='dia útil' AND natureza_delito=='LESA...  1.005283
# natureza_delito=='LESAO CORPORAL'                   1.005056
# dia_tipo=='fim de semana' AND rmbh=='3) Interio...  1.003036
# dia_categoria=='domingo' AND rmbh=='3) Interior...  1.002927
# dia_tipo=='fim de semana'                           1.001570
# rmbh=='3) Interior de MG'                           1.000579
